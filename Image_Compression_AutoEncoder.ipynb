# %% [markdown]
# Image Compression using Auto Encoder

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Define custom loss function
def custom_loss(y_true, y_pred):
    # Custom loss implementation goes here
    # Calculate and return the loss value
    return loss

# Define custom activation function
def custom_activation(x):
    # Custom activation function implementation goes here
    # Apply desired transformations to x and return the result
    return transformed_x

# Define the autoencoder model
def create_autoencoder(input_shape, encoding_dim):
    # Encoder
    input_img = Input(shape=input_shape)
    encoded = Dense(encoding_dim, activation=custom_activation)(input_img)

    # Decoder
    decoded = Dense(input_shape[0], activation=custom_activation)(encoded)

    # Create the autoencoder model
    autoencoder = Model(input_img, decoded)

    # Compile the autoencoder model with custom loss
    autoencoder.compile(optimizer='adam', loss=custom_loss)

    return autoencoder

# Set the input shape and encoding dimension
input_shape = (784,)  # Assuming input images are 28x28 grayscale images
encoding_dim = 32  # Number of neurons in the bottleneck layer

# Create an instance of the autoencoder model
autoencoder = create_autoencoder(input_shape, encoding_dim)

# Display the summary of the autoencoder model
autoencoder.summary()

# Load and preprocess the dataset
# Assuming you have a dataset of images stored in 'x_train'
# Preprocess the dataset as needed

# Train the autoencoder model
autoencoder.fit(x_train, x_train, epochs=10, batch_size=32)

# Use the trained autoencoder to compress and reconstruct the images
compressed_images = autoencoder.predict(x_train)
# Out:
# ...
# 313/313 [==============================] - 5s 15ms/step

# %%
# Display original and compressed images
import matplotlib.pyplot as plt

n = 10  # Number of images to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    plt.title("Original")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Compressed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(compressed_images[i])
    plt.title("Compressed")
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
